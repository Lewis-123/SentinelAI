# %%
from config.environment import WEATHER_API_KEY

from machine_learning.data_pipeline.connectors.weather_api import WeatherAPI



weather = WeatherAPI(
    WEATHER_API_KEY
)


data = weather.get_weather(
    "Nairobi"
)


result = weather.extract_features(
    data
)


result
