# %%
from data_connectors.weather_connector import get_weather


weather = get_weather(
    "Nairobi"
)


weather
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from data_connectors.weather_connector import get_weather
#       2
#       3
#       4 weather = get_weather(
#
# ModuleNotFoundError: No module named 'data_connectors'

# %%
import sys
from pathlib import Path


PROJECT_ROOT = Path.cwd().parent


sys.path.append(
    str(PROJECT_ROOT)
)


print(PROJECT_ROOT)
# Out:
# c:\Users\muche\Documents\GitHub\SentinelAI

# %%
from data_connectors.weather_connector import get_weather


print("Weather connector loaded successfully")
# Out:
# Weather connector loaded successfully

# %%
weather = get_weather(
    "Nairobi"
)


weather
# Out:
# {'location': 'Nairobi',
#  'temperature': 25.93,
#  'humidity': 41,
#  'weather': 'overcast clouds'}
