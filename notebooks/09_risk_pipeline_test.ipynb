# %%
import sys
from pathlib import Path


PROJECT_ROOT = Path.cwd().parent


sys.path.append(
    str(PROJECT_ROOT)
)

# %%
from machine_learning.pipeline.risk_pipeline import run_risk_pipeline

# %%
weather = {

    "rainfall":50,

    "temperature":35,

    "humidity":30

}



population = {

    "population":850000,

    "density":12,

    "poverty_rate":55

}



satellite = {

    "ndvi":0.25

}

# %%
result = run_risk_pipeline(

    weather,

    population,

    satellite

)


result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = run_risk_pipeline(
#       2
#       3     weather,
#       4
#
# File ~\Documents\GitHub\SentinelAI\machine_learning\pipeline\risk_pipeline.py:26, in run_risk_pipeline(weather, population, satellite)
#       7 def run_risk_pipeline(
#       8     weather,
#       9     population,
#      10     satellite
#      11 ):
#      14     features = build_features(
#      15
#      16         weather,
#    (...)     21
#      22     )
# ---> 26     prediction = predict_risk(
#      27
#      28         features.iloc[0].to_dict()
#      29
#      30     )
#      34     return {
#      35
#      36         "risk_score": prediction
#      37
#      38     }
#
# File ~\Documents\GitHub\SentinelAI\backend\services\prediction.py:31, in predict_risk(features)
#      24 def predict_risk(features):
# ...

# %%
result = run_risk_pipeline(

    weather,

    population,

    satellite

)


result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 result = run_risk_pipeline(
#       2
#       3     weather,
#       4
#
# File ~\Documents\GitHub\SentinelAI\machine_learning\pipeline\risk_pipeline.py:26, in run_risk_pipeline(weather, population, satellite)
#       7 def run_risk_pipeline(
#       8     weather,
#       9     population,
#      10     satellite
#      11 ):
#      14     features = build_features(
#      15
#      16         weather,
#    (...)     21
#      22     )
# ---> 26     prediction = predict_risk(
#      27
#      28         features.iloc[0].to_dict()
#      29
#      30     )
#      34     return {
#      35
#      36         "risk_score": prediction
#      37
#      38     }
#
# File ~\Documents\GitHub\SentinelAI\backend\services\prediction.py:31, in predict_risk(features)
#      24 def predict_risk(features):
# ...

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

sys.path.append(
    str(PROJECT_ROOT)
)

print(PROJECT_ROOT)
# Out:
# c:\Users\muche\Documents\GitHub\SentinelAI

# %%
import importlib

import machine_learning.pipeline.feature_builder
import machine_learning.pipeline.risk_pipeline


importlib.reload(
    machine_learning.pipeline.feature_builder
)


importlib.reload(
    machine_learning.pipeline.risk_pipeline
)


from machine_learning.pipeline.risk_pipeline import run_risk_pipeline

# %%
from machine_learning.pipeline.feature_builder import build_features


features = build_features(
    weather,
    population,
    satellite
)


features
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 from machine_learning.pipeline.feature_builder import build_features
#       2
#       3
#       4 features = build_features(
# ----> 5     weather,
#       6     population,
#       7     satellite
#       8 )
#
# NameError: name 'weather' is not defined

# %%
weather = {

    "rainfall": 50,

    "temperature": 35,

    "humidity": 30

}


population = {

    "population": 850000,

    "density": 12,

    "poverty_rate": 55

}


satellite = {

    "ndvi": 0.25

}

# %%
from machine_learning.pipeline.feature_builder import build_features


features = build_features(
    weather,
    population,
    satellite
)


features
# Out:
#    rainfall  temperature  humidity  population  density  poverty_rate
# 0        50           35        30      850000       12            55

# %%
from machine_learning.pipeline.risk_pipeline import run_risk_pipeline


result = run_risk_pipeline(
    weather,
    population,
    satellite
)


result
# Out:
# {'risk_score': np.int64(2)}

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
result = run_risk_pipeline(
    weather,
    population,
    satellite
)

result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = run_risk_pipeline(
#       2     weather,
#       3     population,
#       4     satellite
#
# NameError: name 'run_risk_pipeline' is not defined

# %%
from machine_learning.pipeline.risk_pipeline import run_risk_pipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from machine_learning.pipeline.risk_pipeline import run_risk_pipeline
#
# File ~\Documents\GitHub\SentinelAI\machine_learning\pipeline\risk_pipeline.py:3
#       1 from machine_learning.pipeline.feature_builder import build_features
# ----> 3 from backend.services.prediction import predict_risk
#       7 def run_risk_pipeline(
#       8     weather,
#       9     population,
#      10     satellite
#      11 ):
#      14     features = build_features(
#      15
#      16         weather,
#    (...)     21
#      22     )
#
# ModuleNotFoundError: No module named 'backend'

# %%
import sys
from pathlib import Path


PROJECT_ROOT = Path.cwd().parent


sys.path.append(
    str(PROJECT_ROOT)
)


print(PROJECT_ROOT)
# Out:
# c:\Users\muche\Documents\GitHub\SentinelAI

# %%
from machine_learning.pipeline.risk_pipeline import run_risk_pipeline

# %%
weather = {

    "temperature":40,

    "humidity":20,

    "rainfall":10

}


population = {

    "population":1000000,

    "density":150,

    "poverty_rate":75

}


satellite = {

    "ndvi":0.15,

    "rainfall_anomaly":-40

}

# %%
result = run_risk_pipeline(

    weather,

    population,

    satellite

)


result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 result = run_risk_pipeline(
#       2
#       3     weather,
#       4
#
# File ~\Documents\GitHub\SentinelAI\machine_learning\pipeline\risk_pipeline.py:26, in run_risk_pipeline(weather, population, satellite)
#       7 def run_risk_pipeline(
#       8     weather,
#       9     population,
#      10     satellite
#      11 ):
#      14     features = build_features(
#      15
#      16         weather,
#    (...)     21
#      22     )
# ---> 26     prediction = predict_risk(
#      27
#      28         features.iloc[0].to_dict()
#      29
#      30     )
#      34     return {
#      35
#      36         "risk_score": prediction
#      37
#      38     }
#
# File ~\Documents\GitHub\SentinelAI\backend\services\prediction.py:99, in predict_risk(features, db)
#      87 dataframe = pd.DataFrame(
# ...

# %%
result = run_risk_pipeline(

    weather,

    population,

    satellite

)


result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 result = run_risk_pipeline(
#       2
#       3     weather,
#       4
#
# File ~\Documents\GitHub\SentinelAI\machine_learning\pipeline\risk_pipeline.py:26, in run_risk_pipeline(weather, population, satellite)
#       7 def run_risk_pipeline(
#       8     weather,
#       9     population,
#      10     satellite
#      11 ):
#      14     features = build_features(
#      15
#      16         weather,
#    (...)     21
#      22     )
# ---> 26     prediction = predict_risk(
#      27
#      28         features.iloc[0].to_dict()
#      29
#      30     )
#      34     return {
#      35
#      36         "risk_score": prediction
#      37
#      38     }
#
# File ~\Documents\GitHub\SentinelAI\backend\services\prediction.py:99, in predict_risk(features, db)
#      87 dataframe = pd.DataFrame(
# ...

# %%
from machine_learning.pipeline.feature_builder import build_features

# %%
features = build_features(

    weather,

    population,

    satellite

)


features
# Out:
#    rainfall  temperature  humidity  population  density  poverty_rate
# 0        10           40        20     1000000      150            75

# %%
result = run_risk_pipeline(
    weather,
    population,
    satellite
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 result = run_risk_pipeline(
#       2     weather,
#       3     population,
#       4     satellite
#
# File ~\Documents\GitHub\SentinelAI\machine_learning\pipeline\risk_pipeline.py:26, in run_risk_pipeline(weather, population, satellite)
#       7 def run_risk_pipeline(
#       8     weather,
#       9     population,
#      10     satellite
#      11 ):
#      14     features = build_features(
#      15
#      16         weather,
#    (...)     21
#      22     )
# ---> 26     prediction = predict_risk(
#      27
#      28         features.iloc[0].to_dict()
#      29
#      30     )
#      34     return {
#      35
#      36         "risk_score": prediction
#      37
#      38     }
#
# File ~\Documents\GitHub\SentinelAI\backend\services\prediction.py:99, in predict_risk(features, db)
# ...

# %%
result = run_risk_pipeline(
    weather,
    population,
    satellite
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 result = run_risk_pipeline(
#       2     weather,
#       3     population,
#       4     satellite
#
# File ~\Documents\GitHub\SentinelAI\machine_learning\pipeline\risk_pipeline.py:26, in run_risk_pipeline(weather, population, satellite)
#       7 def run_risk_pipeline(
#       8     weather,
#       9     population,
#      10     satellite
#      11 ):
#      14     features = build_features(
#      15
#      16         weather,
#    (...)     21
#      22     )
# ---> 26     prediction = predict_risk(
#      27
#      28         features.iloc[0].to_dict()
#      29
#      30     )
#      34     return {
#      35
#      36         "risk_score": prediction
#      37
#      38     }
#
# File ~\Documents\GitHub\SentinelAI\backend\services\prediction.py:99, in predict_risk(features, db)
# ...

# %%
features = build_features(
    weather,
    population,
    satellite
)

features
# Out:
#    rainfall  temperature  humidity  population  density  poverty_rate
# 0        10           40        20     1000000      150            75

# %%
result = run_risk_pipeline(
    weather,
    population,
    satellite
)

result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 result = run_risk_pipeline(
#       2     weather,
#       3     population,
#       4     satellite
#
# File ~\Documents\GitHub\SentinelAI\machine_learning\pipeline\risk_pipeline.py:26, in run_risk_pipeline(weather, population, satellite)
#       7 def run_risk_pipeline(
#       8     weather,
#       9     population,
#      10     satellite
#      11 ):
#      14     features = build_features(
#      15
#      16         weather,
#    (...)     21
#      22     )
# ---> 26     prediction = predict_risk(
#      27
#      28         features.iloc[0].to_dict()
#      29
#      30     )
#      34     return {
#      35
#      36         "risk_score": prediction
#      37
#      38     }
#
# File ~\Documents\GitHub\SentinelAI\backend\services\prediction.py:99, in predict_risk(features, db)
# ...

# %%
from machine_learning.pipeline.feature_builder import build_features


features = build_features(
    weather,
    population,
    satellite
)


print(features.columns)

features
# Out:
# Index(['rainfall', 'temperature', 'humidity', 'population', 'density',
#        'poverty_rate'],
#       dtype='str')
#    rainfall  temperature  humidity  population  density  poverty_rate
# 0        10           40        20     1000000      150            75

# %%
import machine_learning.pipeline.feature_builder as fb

print(fb.__file__)
# Out:
# C:\Users\muche\Documents\GitHub\SentinelAI\machine_learning\pipeline\feature_builder.py

# %%
import importlib

import machine_learning.pipeline.feature_builder as fb


importlib.reload(fb)


print(fb.__file__)
# Out:
# C:\Users\muche\Documents\GitHub\SentinelAI\machine_learning\pipeline\feature_builder.py

# %%
features = fb.build_features(
    weather,
    population,
    satellite
)


print(features.columns)

features
# Out:
# Index(['temperature', 'rainfall', 'humidity', 'population', 'density',
#        'poverty_rate', 'ndvi', 'rainfall_anomaly'],
#       dtype='str')
#    temperature  rainfall  humidity  population  density  poverty_rate  ndvi  \
# 0           40        10        20     1000000      150            75  0.15
#
#    rainfall_anomaly
# 0               -40

# %%
result = run_risk_pipeline(

    weather,

    population,

    satellite

)


result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 result = run_risk_pipeline(
#       2
#       3     weather,
#       4
#
# File ~\Documents\GitHub\SentinelAI\machine_learning\pipeline\risk_pipeline.py:26, in run_risk_pipeline(weather, population, satellite)
#       7 def run_risk_pipeline(
#       8     weather,
#       9     population,
#      10     satellite
#      11 ):
#      14     features = build_features(
#      15
#      16         weather,
#    (...)     21
#      22     )
# ---> 26     prediction = predict_risk(
#      27
#      28         features.iloc[0].to_dict()
#      29
#      30     )
#      34     return {
#      35
#      36         "risk_score": prediction
#      37
#      38     }
#
# File ~\Documents\GitHub\SentinelAI\backend\services\prediction.py:99, in predict_risk(features, db)
#      87 dataframe = pd.DataFrame(
# ...

# %%
from machine_learning.pipeline.risk_pipeline import run_risk_pipeline

# %%
result = run_risk_pipeline(
    weather,
    population,
    satellite
)

result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 result = run_risk_pipeline(
#       2     weather,
#       3     population,
#       4     satellite
#
# File ~\Documents\GitHub\SentinelAI\machine_learning\pipeline\risk_pipeline.py:26, in run_risk_pipeline(weather, population, satellite)
#       7 def run_risk_pipeline(
#       8     weather,
#       9     population,
#      10     satellite
#      11 ):
#      14     features = build_features(
#      15
#      16         weather,
#    (...)     21
#      22     )
# ---> 26     prediction = predict_risk(
#      27
#      28         features.iloc[0].to_dict()
#      29
#      30     )
#      34     return {
#      35
#      36         "risk_score": prediction
#      37
#      38     }
#
# File ~\Documents\GitHub\SentinelAI\backend\services\prediction.py:99, in predict_risk(features, db)
# ...

# %%
import backend.services.prediction as pred

print(pred.__file__)
# Out:
# c:\Users\muche\Documents\GitHub\SentinelAI\backend\services\prediction.py

# %%
import importlib
import backend.services.prediction as pred

importlib.reload(pred)

print(pred.__file__)
# Out:
# Loaded model: C:\Users\muche\Documents\GitHub\SentinelAI\machine_learning\models\risk_classifier.pkl
# Model features: ['temperature' 'rainfall' 'humidity' 'population' 'density' 'poverty_rate'
#  'ndvi' 'rainfall_anomaly']
# c:\Users\muche\Documents\GitHub\SentinelAI\backend\services\prediction.py

# %%
import machine_learning.pipeline.risk_pipeline as rp

importlib.reload(rp)
# Out:
# <module 'machine_learning.pipeline.risk_pipeline' from 'C:\\Users\\muche\\Documents\\GitHub\\SentinelAI\\machine_learning\\pipeline\\risk_pipeline.py'>

# %%
from machine_learning.pipeline.risk_pipeline import run_risk_pipeline

# %%
result = run_risk_pipeline(

    weather,

    population,

    satellite

)

result
# Out:
# Index(['temperature', 'rainfall', 'humidity', 'population', 'density',
#        'poverty_rate', 'ndvi', 'rainfall_anomaly'],
#       dtype='str')
#
# PREDICTION INPUT FEATURES
# Index(['temperature', 'rainfall', 'humidity', 'population', 'density',
#        'poverty_rate', 'ndvi', 'rainfall_anomaly'],
#       dtype='str')
#    temperature  rainfall  humidity  population  density  poverty_rate  ndvi  \
# 0         40.0      10.0      20.0   1000000.0    150.0          75.0  0.15
#
#    rainfall_anomaly
# 0             -40.0
# {'risk_score': {'risk_level': 'HIGH',
#   'risk_score': 100,
#   'confidence': np.float64(98.5),
#   'model_prediction': '0',
#   'features': {'temperature': 40.0,
#    'rainfall': 10.0,
#    'humidity': 20.0,
#    'population': 1000000.0,
#    'density': 150.0,
#    'poverty_rate': 75.0,
#    'ndvi': 0.15,
#    'rainfall_anomaly': -40.0}}}

# %%
result = run_risk_pipeline(

    weather,

    population,

    satellite

)


result
# Out:
# Index(['temperature', 'rainfall', 'humidity', 'population', 'density',
#        'poverty_rate', 'ndvi', 'rainfall_anomaly'],
#       dtype='str')
#
# PREDICTION INPUT FEATURES
# Index(['temperature', 'rainfall', 'humidity', 'population', 'density',
#        'poverty_rate', 'ndvi', 'rainfall_anomaly'],
#       dtype='str')
#    temperature  rainfall  humidity  population  density  poverty_rate  ndvi  \
# 0         40.0      10.0      20.0   1000000.0    150.0          75.0  0.15
#
#    rainfall_anomaly
# 0             -40.0
# {'risk_score': {'risk_level': 'HIGH',
#   'risk_score': 100,
#   'confidence': np.float64(98.5),
#   'model_prediction': '0',
#   'features': {'temperature': 40.0,
#    'rainfall': 10.0,
#    'humidity': 20.0,
#    'population': 1000000.0,
#    'density': 150.0,
#    'poverty_rate': 75.0,
#    'ndvi': 0.15,
#    'rainfall_anomaly': -40.0}}}
