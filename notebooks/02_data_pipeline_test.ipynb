# %%
from machine_learning.data_pipeline.data_loader import load_dataset
from machine_learning.data_pipeline.data_cleaner import clean_dataset


data = load_dataset(
    "raw/weather/weather_sample.csv"
)


print(data.head())


cleaned = clean_dataset(data)


print(cleaned.head())
