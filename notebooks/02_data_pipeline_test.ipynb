# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

sys.path.append(str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# c:\Users\muche\Documents\GitHub\SentinelAI

# %%
from machine_learning.data_pipeline.data_loader import load_dataset

print("SentinelAI pipeline imported successfully")
# Out:
# SentinelAI pipeline imported successfully
